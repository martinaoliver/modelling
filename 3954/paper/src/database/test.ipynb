# %%
#############
###paths#####
#############
import sys
import os

from importlib_metadata import distribution
pwd = os.getcwd()
modellingpath = pwd.rpartition("modelling")[0] + pwd.rpartition("modelling")[1] 
sys.path.append(modellingpath + '/lib')
#############
import pickle 
import pandas as pd
import psycopg2
import numpy
from sqlalchemy import types

# %%
circuit_n='circuit14'
# variant='2nd'
variant='fitted2'
n_species=6
# Specifiy number of parameter sets in parameterset file to be loaded
n_param_sets = 2000000
balance = 'balanced'
# lsa_df= pickle.load( open(modellingpath + '/3954/paper/out/analytical/lsa_dataframes/turing_dataframes/turing_df_%s_variant%s_%rparametersets_%s.pkl'%(circuit_n,variant,n_param_sets, balance), "rb"))
# input_df= pickle.load( open(modellingpath + '/3954/paper/input/balanced_parameterfiles/df_%s_variant%s_%rparametersets_%s.pkl'%(circuit_n,variant,n_param_sets, balance), "rb"))
input_df= pickle.load( open(modellingpath + '/3954/paper/input/fitted_parameterfiles/df_%s_variant%s_%rparametersets.pkl'%(circuit_n,variant,n_param_sets), "rb"))

input_df.insert(0, 'circuit_n', circuit_n)
input_df.insert(1, 'variant', variant)
input_df.insert(2, 'n_param_sets', n_param_sets)
input_df.index.name = 'parID'
input_df
# Out:
#          circuit_n  variant  n_param_sets        Dr          Va          Vb  \
# parID
# 0        circuit14  fitted2       2000000  0.030799  123.549504  133.657088
# 1        circuit14  fitted2       2000000  0.019851   51.218933  168.962574
# 2        circuit14  fitted2       2000000  0.005690  219.420656   43.950058
# 3        circuit14  fitted2       2000000  0.003599  377.923830  295.078700
# 4        circuit14  fitted2       2000000  0.099524   13.891513   14.424904
# ...            ...      ...           ...       ...         ...         ...
# 1999995  circuit14  fitted2       2000000  0.280592   94.568089   22.710578
# 1999996  circuit14  fitted2       2000000  0.599564   48.821368   17.141688
# 1999997  circuit14  fitted2       2000000  0.179543  861.573100   84.175805
# 1999998  circuit14  fitted2       2000000  0.009222  148.516647  150.943628
# 1999999  circuit14  fitted2       2000000  0.102292   17.643156  507.251878
#
# ...

# %%
credentials="postgresql://postgres:postgres@localhost:5432/mo2016"
input_df.to_sql('model_params', con=credentials, if_exists='append', index=True)
# Out:
# 1000

# %%
def createSqlFormat():
    modelParamsDf = 
    lsaOutputDf =

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/bt/1cqt3cks1sl9cz4dfwlyxhpm0000gn/T/ipykernel_8167/3964976774.py in <module>
# ----> 1 lsa_df1 = lsa_df.droplevel(-1).drop_duplicates()
#       2 lsa_df1
#
# ~/opt/anaconda3/envs/condaenv/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ~/opt/anaconda3/envs/condaenv/lib/python3.8/site-packages/pandas/core/frame.py in drop_duplicates(self, subset, keep, inplace, ignore_index)
#    6667         inplace = validate_bool_kwarg(inplace, "inplace")
#    6668         ignore_index = validate_bool_kwarg(ignore_index, "ignore_index")
# ...

# %%
#connect to database
with psycopg2.connect(
    host="localhost",
    database="mo2016",
    user="postgres",
    password="postgres") as conn:
    pass

# %%
# lsa_df= pickle.load( open(modellingpath + '/3954/paper/out/analytical/lsa_dataframes/all_dataframes/lsa_df_%s_variant%s_%rparametersets_%s.pkl'%(circuit_n,variant,n_param_sets, balance), "rb"))
# pickle.dump(results_df, open(modellingpath + '/3954/paper/out/analytical/lsa_dataframes/all_dataframes/lsa_df_%s_variant%s_%rparametersets_%s.pkl'%(circuit_n,variant,n_param_sets,balance), 'wb'))
# lsa_df.drop(columns=['maxeig','ss_list'], inplace=True)
# lsa_df.drop(columns=['maxeig'], inplace=True)

# input_df['circuit_n'] = circuit_n

# %%
dtypes = {
    'ss_list' : types.ARRAY(types.FLOAT()), 
    'maxeig' : types.ARRAY(types.FLOAT())
}
credentials="postgresql://postgres:postgres@localhost:5432/mo2016"
lsa_df.to_sql('modelParams', con=credentials, if_exists='append', index=False, dtype=dtypes)
# Out:
# 176
