# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.fft import fft, ifft

# %% [markdown]
# Step function

# %%
x1 = np.linspace(-3,3,1200)
# y = [0,1,1,1,0]
# fx = np.sin(x)
y1=[]
for n in range(1200):
    if n<400:
        y1.append(0)
    elif n<800:
        y1.append(1)
    else:
        y1.append(0)

# %%
x2 = np.linspace(-3,3,1200)
# y = [0,1,1,1,0]
# fx = np.sin(x)
y2=[]
for n in range(1200):
    if n<200:
        y2.append(0)
    elif n<1000:
        y2.append(1)
    else:
        y2.append(0)

# %%
fig,ax = plt.subplots()
plt.step(x1,y1)
plt.show()
plt.step(x2,y2)
plt.show()

# ax[1]=plt.plot(x2,y2)

# %%
fft(y1)
plt.hist(fft(y1),bins=120)
plt.show()

fft(y2)
plt.hist(fft(y2),bins=120)
plt.show()
fft(y1)
# Out:
# array([ 4.00000000e+02-0.00000000e+00j, -3.30796582e+02-8.66025404e-01j,
#         1.65397157e+02+8.66025404e-01j, ...,
#         1.15143067e-16+6.56392645e-15j,  1.65397157e+02-8.66025404e-01j,
#        -3.30796582e+02+8.66025404e-01j])

# %% [markdown]
# ## Sinusoidal

# %%
x = np.linspace(0,2*np.pi,30)
fx = np.sin(2*x)
plt.plot(x,fx)

# %%
FT=fft(fx)
FT_real=np.real(FT)
FT_imag=np.imag(FT)

# len(FT_real)
# FT_real
# plt.hist(FT)
plt.scatter(x,FT_real)
plt.show()
plt.scatter(x,FT_imag)

# %%
FT_real
# Out:
# array([-1.88737914e-15,  6.50085073e-02,  3.04029223e+00, -4.06823072e-01,
#        -2.91322026e-01, -2.57553008e-01, -2.42362501e-01, -2.34107567e-01,
#        -2.29116532e-01, -2.25894048e-01, -2.23729984e-01, -2.22251244e-01,
#        -2.21248362e-01, -2.20599548e-01, -2.20234523e-01, -2.20116645e-01,
#        -2.20234523e-01, -2.20599548e-01, -2.21248362e-01, -2.22251244e-01,
#        -2.23729984e-01, -2.25894048e-01, -2.29116532e-01, -2.34107567e-01,
#        -2.42362501e-01, -2.57553008e-01, -2.91322026e-01, -4.06823072e-01,
#         3.04029223e+00,  6.50085073e-02])

# %%
x = np.linspace(0,2*np.pi,10)
fx = np.sin(x)
plt.plot(x,fx)

# %%
FT=fft(fx)
FT_real=np.real(FT)
FT_imag=np.imag(FT)

# len(FT_real)
# FT_real
# plt.hist(FT)
plt.scatter(x,FT_real)
plt.show()
plt.scatter(x,FT_imag)

# %% [markdown]
# ## 2D

# %% [markdown]
# read https://thepythoncodingbook.com/2021/08/30/2d-fourier-transform-in-python-and-fourier-synthesis-of-images/ for more info

# %% [markdown]
# ### Case 1

# %%
x=np.linspace(0,5,1000)
y=np.linspace(0,5,1000)
X,Y=np.meshgrid(x,y)

fxy= np.sin(4*np.pi*X)+np.cos(6*np.pi*Y)
plt.subplot(121)
plt.imshow(fxy)

#The inverse of fftshift. Although identical for even-length x, the functions differ by one sample for odd-length x.
ft = np.fft.ifftshift(fxy) 

#Compute the 2-dimensional discrete Fourier Transform (fast fourier transform).
ft = np.fft.fft2(ft)

#Shift the zero-frequency component to the center of the spectrum.
ft = np.fft.fftshift(ft)

plt.subplot(122)
plt.imshow(np.abs(ft))
plt.xlim(480,520)
plt.ylim(480,520)

plt.show()

# %% [markdown]
# ### Case 2

# %%
x=np.linspace(0,5,1000)
y=np.linspace(0,5,1000)
X,Y=np.meshgrid(x,y)

fxy= np.sin(2*np.pi*X + 3*np.pi*Y)
plt.subplot(121)
plt.imshow(fxy)


ft = np.fft.ifftshift(fxy)
ft = np.fft.fft2(ft)
ft = np.fft.fftshift(ft)
plt.subplot(122)
plt.imshow(np.abs(ft))
plt.xlim(480,520)
plt.ylim(480,520)

plt.show()

# %%
plt.imshow(np.real(fftxy))

# %%
plt.imshow(np.imag(fftxy))
